# %%
from pandas import DataFrame, Series
import pandas as pd
import numpy as np
import matplotlib as plt
import json
import tweepy

# %%
data_path = '../data/out_detail.json'
tweets = json.load(open(data_path))

# %%
df = DataFrame(tweets)
df.head()
# Out:
#    accessLevel contributors      createdAt  currentUserRetweetId  \
# 0            0           []  1457634093000                    -1
# 1            0           []  1457628053000                    -1
# 2            0           []  1457627634000                    -1
# 3            0           []  1457627612000                    -1
# 4            0           []  1457627458000                    -1
#
#   extendedMediaEntities  favoriteCount  \
# 0                    []              0
# 1                    []              0
# 2                    []              0
# 3                    []              3
# 4                    []              1
#
#                                          geoLocation  \
# 0  {u'latitude': 53.3893393, u'longitude': -2.922...
# 1                                               None
# 2                                               None
# 3  {u'latitude': 53.40783846, u'longitude': -2.98...
# 4    {u'latitude': 53.40773, u'longitude': -2.98324}
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 0 to 13
# Data columns (total 34 columns):
# accessLevel              14 non-null int64
# contributors             14 non-null object
# createdAt                14 non-null int64
# currentUserRetweetId     14 non-null int64
# extendedMediaEntities    14 non-null object
# favoriteCount            14 non-null int64
# geoLocation              6 non-null object
# hashtagEntities          14 non-null object
# id                       14 non-null int64
# inReplyToScreenName      1 non-null object
# inReplyToStatusId        14 non-null int64
# inReplyToUserId          14 non-null int64
# isFavorited              14 non-null bool
# isPossiblySensitive      14 non-null bool
# isRetweeted              14 non-null bool
# isTruncated              14 non-null bool
# lang                     14 non-null object
# mediaEntities            14 non-null object
# place                    6 non-null object
# ...

# %%
df.describe().transpose()
# Out:
#                      count         mean          std          min  \
# accessLevel             14            0            0            0
# createdAt               14  1.45762e+12    2.925e+07   1.4576e+12
# currentUserRetweetId    14           -1            0           -1
# favoriteCount           14     0.714286      1.72888            0
# id                      14  7.07941e+17  1.22684e+14  7.07856e+17
# inReplyToStatusId       14  5.05948e+16  1.89308e+17           -1
# inReplyToUserId         14  4.03338e+07  1.50915e+08           -1
# isFavorited             14            0            0        False
# isPossiblySensitive     14            0            0        False
# isRetweeted             14            0            0        False
# isTruncated             14            0            0        False
# quotedStatusId          14           -1            0           -1
# retweet                 14     0.571429     0.513553        False
# ...

# %%
tzs = df['userTimezone'].value_counts()[:10]
print tzs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-5521b5e51283> in <module>()
# ----> 1 tzs = df['userTimezone'].value_counts()[:10]
#       2 print tzs
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# ...
